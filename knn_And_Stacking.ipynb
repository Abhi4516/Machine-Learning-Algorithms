# %%
import pandas as pd 
import numpy as np
from sklearn.model_selection import train_test_split , GridSearchCV
from sklearn.metrics import accuracy_score , confusion_matrix , roc_auc_score , roc_curve
from pandas_profiling import ProfileReport
from sklearn.neighbors import KNeighborsClassifier
from sklearn.preprocessing import StandardScaler
from ydata_profiling import ProfileReport
# Out:
# C:\Users\ASUS ZenBook\AppData\Local\Temp\ipykernel_13452\1550281364.py:5: DeprecationWarning: `import pandas_profiling` is going to be deprecated by April 1st. Please use `import ydata_profiling` instead.
#   from pandas_profiling import ProfileReport

# %%
data=pd.read_csv('D:\Datasets\winequality-red.csv')

# %%
data.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality
# 0      9.4        5
# 1      9.8        5
# 2      9.8        5
# ...

# %%
x=data.drop(columns='quality')

# %%
y=data.quality

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,train_size=0.7,random_state=30)

# %%
#                                    KNN

# %%
knn1=KNeighborsClassifier(n_neighbors=30,p=1)

# %%
knn1.fit(x_train,y_train)
# Out:
# KNeighborsClassifier(n_neighbors=30, p=1)

# %%
knn1.score(x_train,y_train)
# Out:
# 0.5549597855227882

# %%
knn1.score(x_test,y_test)
# Out:
# 0.5541666666666667

# %%
parm={
     'n_neighbors':[3,5,6,8,9,15,20,25,30,32,40],
    'algorithm':['ball_tree', 'kd_tree', 'brute'],
    'p':[1,2],
    'leaf_size':[10,20,25,30,39,15],
    'weights':['uniform', 'distance']
}

# %%
gcv=GridSearchCV(knn1,param_grid=parm)

# %%
gcv.fit(x_train,y_train)
# Out:
# C:\Users\ASUSZenBook\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py:824: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\ASUSZenBook\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py", line 813, in _score
#     scores = scorer(estimator, X_test, y_test)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\ASUSZenBook\anaconda3\Lib\site-packages\sklearn\metrics\_scorer.py", line 527, in __call__
#     return estimator.score(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\ASUSZenBook\anaconda3\Lib\site-packages\sklearn\base.py", line 705, in score
#     return accuracy_score(y, self.predict(X), sample_weight=sample_weight)
#                              ^^^^^^^^^^^^^^^
# ...

# %%
gcv.score(x_test,y_test)
# Out:
# 0.65

# %%
gcv.best_params_
# Out:
# {'algorithm': 'ball_tree',
#  'leaf_size': 10,
#  'n_neighbors': 40,
#  'p': 1,
#  'weights': 'distance'}

# %%
knn_new=KNeighborsClassifier(algorithm='ball_tree',leaf_size=10,n_neighbors=40,p=1,weights='distance')

# %%
knn_new.fit(x_train,y_train)
# Out:
# KNeighborsClassifier(algorithm='ball_tree', leaf_size=10, n_neighbors=40, p=1,
#                      weights='distance')

# %%
knn_new.score(x_test,y_test)
# Out:
# 0.65

# %%
import pickle

# %%
pickle.dump(knn_new,open('knn_new.pkl','wb'))

# %%
pwd
# Out:
# 'C:\\Users\\ASUS ZenBook\\Data Science & AI\\Machine Learning\\ineuron\\Knn,Stacking'

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
lg=RandomForestClassifier()

# %%
lg.fit(x_train,y_train)
# Out:
# RandomForestClassifier()

# %%
lg.score(x_test,y_test)
# Out:
# 0.6833333333333333

# %%
#                               SVM

# %%
from sklearn.svm import SVC

# %%
sv=SVC()

# %%
sv.fit(x_train,y_train)
# Out:
# SVC()

# %%
sv.score(x_test,y_test)
# Out:
# 0.53125

# %%
pram={
    'kernel':['linear', 'poly', 'rbf', 'sigmoid', 'precomputed']
  
    
    
}

# %%
gcv=GridSearchCV(estimator=sv,param_grid=pram)

# %%
#                       STACKING

# %%
data.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality
# 0      9.4        5
# 1      9.8        5
# 2      9.8        5
# ...

# %%
x=data.drop(columns='quality')

# %%
y=data.quality

# %%
train,val_train,test,val_test=train_test_split(x,y,random_state=3,test_size=.50)

# %%
x_train,x_test,y_train,y_test=train_test_split(train,test,random_state=3,test_size=.2)

# %%
knn=KNeighborsClassifier()

# %%
knn.fit(x_train,y_train)
# Out:
# KNeighborsClassifier()

# %%
knn.score(x_test,y_test)
# Out:
# 0.425

# %%
svc=SVC()
svc.fit(x_train,y_train)
# Out:
# SVC()

# %%
svc.score(x_test,y_test)
# Out:
# 0.44375

# %%
predcition_knn = knn.predict(val_train)
prediction_svc = svc.predict(val_train)

# %%
input3=np.column_stack((predcition_knn,prediction_svc))

# %%
output=val_test

# %%
rf=RandomForestClassifier()

# %%
rf.fit(input3,output)
# Out:
# RandomForestClassifier()

# %%
rf.score(input3,output)
# Out:
# 0.51375

# %%
# for testing first pass the data on first 2 model then combine

# %%
out_predcition_knn = knn.predict(x_test)
out_prediction_svc = svc.predict(x_test)

# %%
out_input3=np.column_stack((predcition_knn,prediction_svc))

# %%
rf.score(out_input3,y_test)
# Out:
# 0.4375
