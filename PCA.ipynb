# %%
import numpy as np
import pandas as pd

# %%
A = np.array([
        [ 3,  7],
        [-4, -6],
        [ 7,  8],
        [ 1, -1],
        [-4, -1],
        [-3, -7]
])

# %%
A.shape
# Out:
# (6, 2)

# %%
A.mean()
# Out:
# 0.0

# %%
df=pd.DataFrame(A,columns=['a0','a1'])

# %%
df
# Out:
#    a0  a1
# 0   3   7
# 1  -4  -6
# 2   7   8
# 3   1  -1
# 4  -4  -1
# 5  -3  -7

# %%
a0=A[:,0]

# %%
a1=A[:,1]

# %%
np.cov(a0,a1)
# Out:
# array([[20., 25.],
#        [25., 40.]])

# %%
np.var(a1)
# Out:
# 33.333333333333336

# %%
np.sum(a0*a1/5)
# Out:
# 25.0

# %%
A.T
# Out:
# array([[ 3, -4,  7,  1, -4, -3],
#        [ 7, -6,  8, -1, -1, -7]])

# %%
sigma=A.T@A/5

# %%
sigma
# Out:
# array([[20., 25.],
#        [25., 40.]])

# %%
l,x=np.linalg.eig(sigma)

# %%
l
# Out:
# array([ 3.07417596, 56.92582404])

# %%
x
# Out:
# array([[-0.82806723, -0.56062881],
#        [ 0.56062881, -0.82806723]])

# %%
sigma@x[:,0]
# Out:
# array([-2.54562438,  1.72347161])

# %%
sigma@x[:,1]
# Out:
# array([-31.91425695, -47.13840945])

# %%
print('first pc1')
x[:,1]
# Out:
# first pc1
# array([-0.56062881, -0.82806723])

# %%
print('second pc2')
x[:,0]
# Out:
# second pc2
# array([-0.82806723,  0.56062881])

# %%
pc1_arr=x[:,0]

# %%
pc2_arr=x[:,1]

# %%
pc1_arr
# Out:
# array([-0.82806723,  0.56062881])

# %%
pc2_arr
# Out:
# array([-0.56062881, -0.82806723])

# %%
df=pd.read_csv(r'D:\360DIGITMG\Machine Learning\DataSet\glass.csv')

# %%
df.head()
# Out:
#         RI     Na    Mg    Al     Si     K    Ca   Ba   Fe  Type
# 0  1.52101  13.64  4.49  1.10  71.78  0.06  8.75  0.0  0.0     1
# 1  1.51761  13.89  3.60  1.36  72.73  0.48  7.83  0.0  0.0     1
# 2  1.51618  13.53  3.55  1.54  72.99  0.39  7.78  0.0  0.0     1
# 3  1.51766  13.21  3.69  1.29  72.61  0.57  8.22  0.0  0.0     1
# 4  1.51742  13.27  3.62  1.24  73.08  0.55  8.07  0.0  0.0     1

# %%
df.std()
# Out:
# RI      0.003037
# Na      0.816604
# Mg      1.442408
# Al      0.499270
# Si      0.774546
# K       0.652192
# Ca      1.423153
# Ba      0.497219
# Fe      0.097439
# Type    2.103739
# dtype: float64

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
df_scaled = scaler.fit_transform(df)

# %%
df1=pd.DataFrame(df_scaled)

# %%
df1.describe()
# Out:
#                   0             1             2             3             4  \
# count  2.140000e+02  2.140000e+02  2.140000e+02  2.140000e+02  2.140000e+02
# mean  -2.877034e-14  2.191393e-15 -1.328117e-16 -2.988264e-16  9.525091e-16
# std    1.002345e+00  1.002345e+00  1.002345e+00  1.002345e+00  1.002345e+00
# min   -2.381516e+00 -3.286943e+00 -1.865511e+00 -2.318616e+00 -3.676472e+00
# 25%   -6.082728e-01 -6.141580e-01 -3.957744e-01 -5.117560e-01 -4.800288e-01
# 50%   -2.262293e-01 -1.323817e-01  5.527787e-01 -1.704602e-01  1.799655e-01
# 75%    2.614331e-01  5.120326e-01  6.361680e-01  3.715977e-01  5.649621e-01
# max    5.137232e+00  4.875637e+00  1.254639e+00  4.125851e+00  3.570524e+00
#
#                   5             6             7             8             9
# count  2.140000e+02  2.140000e+02  2.140000e+02  2.140000e+02  2.140000e+02
# m
#          1.80224300e-01, -4.16539925e-01, -5.76459169e-01,
#         -3.10928479e-02],
#        [ 4.42662921e-01, -6.07674893e-02,  3.58029831e-01,
#          1.06455896e-01,  1.79819491e-02,  5.44316899e-02,
#          7.10375870e-01,  1.65829179e-01, -1.92869971e-01,
#         -2.97019282e-01],
#        [ 1.22202175e-01, -2.39827307e-01, -4.73860024e-01,
#          6.36660969e-01,  1.18984418e-02,  1.10903123e-01,
# ...

# %%
pc1_data=df_scaled@x[:,0]

# %%
pc2_data=df_scaled@x[:,1]

# %%
pc1_data.T
# Out:
# array([-1.55407028, -0.39260231, -0.20404462, -0.80994681, -0.70120086,
#        -0.867269  , -0.78087621, -0.91985918, -0.60182549, -0.94141289,
#        -0.81666354, -0.95448048, -0.88279356, -1.12570769, -0.92619738,
#        -0.89733636, -1.12026872, -1.46701343, -0.97764111, -0.58995079,
#        -1.0677603 , -1.50665422, -0.96375527, -0.8449589 , -0.77136711,
#        -0.89749476, -0.68780142, -0.77325204, -0.85275531, -0.82148071,
#        -1.20010992, -0.95935879, -1.22983844, -0.92660044, -0.95592325,
#        -0.63932257, -0.70278556, -0.90548007, -1.89587225, -1.89587225,
#        -1.09175664, -0.96161603, -0.72305668, -1.88306367, -1.53916199,
#        -0.90169263, -1.23704222, -2.35697896, -2.0210454 , -0.90028604,
#        -2.44742153, -1.18960657, -0.68859954, -0.74345965, -0.77566324,
#        -1.17741923, -0.99024089, -0.90564836, -0.72764938, -0.96883099,
#        -1.01818519, -0.38552104, -1.94890154, -1.73770258, -1.82327273,
# ...

# %%
from sklearn.decomposition import PCA

# %%
pca=PCA(n_components=2)

# %%
pca.fit_transform(df1)
# Out:
# array([[-1.55407028e+00,  1.61464196e-01],
#        [-3.92602313e-01, -1.09023459e+00],
#        [-2.04044624e-01, -1.44432873e+00],
#        [-8.09946813e-01, -9.69748260e-01],
#        [-7.01200863e-01, -1.18534336e+00],
#        [-8.67269000e-01, -1.32809386e+00],
#        [-7.80876206e-01, -1.13904843e+00],
#        [-9.19859176e-01, -1.12800155e+00],
#        [-6.01825489e-01, -4.28681840e-01],
#        [-9.41412889e-01, -9.46577545e-01],
#        [-8.16663538e-01, -1.42103720e+00],
#        [-9.54480479e-01, -9.82486039e-01],
#        [-8.82793560e-01, -1.40192066e+00],
#        [-1.12570769e+00, -9.63762596e-01],
#        [-9.26197382e-01, -1.08136025e+00],
#        [-8.97336362e-01, -1.08166783e+00],
#        [-1.12026872e+00, -9.16856535e-01],
#        [-1.46701343e+00,  8.23605221e-01],
#        [-9.77641110e-01, -3.26966535e-02],
#        [-5.89950787e-01, -9.27687817e-01],
#        [-1.06776030e+00, -7.71239659e-01],
#        [-1.50665422e+00,  3.02546321e-01],
# ...

# %%
import matplotlib.pyplot as plt

# %%
pca = PCA()

# %%
principal_component = pca.fit_transform(df1)

# %%
pca.explained_variance_ratio_
# Out:
# array([3.05559742e-01, 2.29133794e-01, 1.40942403e-01, 1.16632574e-01,
#        9.14084695e-02, 5.47422471e-02, 3.69434911e-02, 1.82674245e-02,
#        6.20907493e-03, 1.60779713e-04])

# %%
plt.figure()
plt.plot(np.cumsum(pca.explained_variance_ratio_),linewidth=4)
plt.xlabel('dimension')
plt.ylabel('EVR')
# Out:
# Text(0, 0.5, 'EVR')

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df=pd.read_csv(r'D:\360DIGITMG\Machine Learning\DataSet\glass.csv')

# %%
df.head()
# Out:
#         RI     Na    Mg    Al     Si     K    Ca   Ba   Fe  Type
# 0  1.52101  13.64  4.49  1.10  71.78  0.06  8.75  0.0  0.0     1
# 1  1.51761  13.89  3.60  1.36  72.73  0.48  7.83  0.0  0.0     1
# 2  1.51618  13.53  3.55  1.54  72.99  0.39  7.78  0.0  0.0     1
# 3  1.51766  13.21  3.69  1.29  72.61  0.57  8.22  0.0  0.0     1
# 4  1.51742  13.27  3.62  1.24  73.08  0.55  8.07  0.0  0.0     1

# %%
df=df.rename(columns={'Type':'Class'})

# %%
df.head()
# Out:
#         RI     Na    Mg    Al     Si     K    Ca   Ba   Fe  Class
# 0  1.52101  13.64  4.49  1.10  71.78  0.06  8.75  0.0  0.0      1
# 1  1.51761  13.89  3.60  1.36  72.73  0.48  7.83  0.0  0.0      1
# 2  1.51618  13.53  3.55  1.54  72.99  0.39  7.78  0.0  0.0      1
# 3  1.51766  13.21  3.69  1.29  72.61  0.57  8.22  0.0  0.0      1
# 4  1.51742  13.27  3.62  1.24  73.08  0.55  8.07  0.0  0.0      1

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 214 entries, 0 to 213
# Data columns (total 10 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   RI      214 non-null    float64
#  1   Na      214 non-null    float64
#  2   Mg      214 non-null    float64
#  3   Al      214 non-null    float64
#  4   Si      214 non-null    float64
#  5   K       214 non-null    float64
#  6   Ca      214 non-null    float64
#  7   Ba      214 non-null    float64
#  8   Fe      214 non-null    float64
#  9   Class   214 non-null    int64
# dtypes: float64(9), int64(1)
# memory usage: 16.8 KB

# %%
df.shape
# Out:
# (214, 10)

# %%
df=df.reset_index()

# %%
df.head()
# Out:
#    index       RI     Na    Mg    Al     Si     K    Ca   Ba   Fe  Class
# 0      0  1.52101  13.64  4.49  1.10  71.78  0.06  8.75  0.0  0.0      1
# 1      1  1.51761  13.89  3.60  1.36  72.73  0.48  7.83  0.0  0.0      1
# 2      2  1.51618  13.53  3.55  1.54  72.99  0.39  7.78  0.0  0.0      1
# 3      3  1.51766  13.21  3.69  1.29  72.61  0.57  8.22  0.0  0.0      1
# 4      4  1.51742  13.27  3.62  1.24  73.08  0.55  8.07  0.0  0.0      1

# %%
df.shape
# Out:
# (214, 11)

# %%
df.isna().sum()
# Out:
# index    0
# RI       0
# Na       0
# Mg       0
# Al       0
# Si       0
# K        0
# Ca       0
# Ba       0
# Fe       0
# Class    0
# dtype: int64

# %%
data=df.drop(labels=['index','Class'],axis=1)

# %%
data.head()
# Out:
#         RI     Na    Mg    Al     Si     K    Ca   Ba   Fe
# 0  1.52101  13.64  4.49  1.10  71.78  0.06  8.75  0.0  0.0
# 1  1.51761  13.89  3.60  1.36  72.73  0.48  7.83  0.0  0.0
# 2  1.51618  13.53  3.55  1.54  72.99  0.39  7.78  0.0  0.0
# 3  1.51766  13.21  3.69  1.29  72.61  0.57  8.22  0.0  0.0
# 4  1.51742  13.27  3.62  1.24  73.08  0.55  8.07  0.0  0.0

# %%
data.mean()
# Out:
# RI     1.518365
# Na    13.407850
# Mg     2.684533
# Al     1.444907
# Si    72.650935
# K      0.497056
# Ca     8.956963
# Ba     0.175047
# Fe     0.057009
# dtype: float64

# %%
from sklearn.preprocessing import StandardScaler

# %%
sc=StandardScaler()
data=sc.fit_transform(data)

# %%
data=pd.DataFrame(data,columns=data.columns)

# %%
data.describe()
# Out:
#                RI          Na          Mg          Al          Si           K  \
# count  214.000000  214.000000  214.000000  214.000000  214.000000  214.000000
# mean     1.518365   13.407850    2.684533    1.444907   72.650935    0.497056
# std      0.003037    0.816604    1.442408    0.499270    0.774546    0.652192
# min      1.511150   10.730000    0.000000    0.290000   69.810000    0.000000
# 25%      1.516522   12.907500    2.115000    1.190000   72.280000    0.122500
# 50%      1.517680   13.300000    3.480000    1.360000   72.790000    0.555000
# 75%      1.519157   13.825000    3.600000    1.630000   73.087500    0.610000
# max      1.533930   17.380000    4.490000    3.500000   75.410000    6.210000
#
#                Ca          Ba          Fe
# count  214.000000  214.000000  214.000000
# mean     8.956963    0.175047    0.057009
# std      1.423153    0.497219    0.097439
# min      5.430000    0.000000    0.000000
# 25%      8.240000    0.000000    0.000000
# ...

# %%
from sklearn.decomposition import PCA

# %%
pca=PCA()
pca.fit_transform(data)
# Out:
# array([[-1.43142469e+00, -1.10211499e+00, -1.06695840e+00, ...,
#         -6.77563850e-02,  1.13765010e-02, -9.44871904e-04],
#        [-1.43670679e+00,  3.43585271e-01, -2.77823603e-01, ...,
#         -4.31684324e-02, -1.70475229e-02, -9.55410401e-04],
#        [-1.42732181e+00,  3.45720096e-01,  1.38707610e-01, ...,
#         -4.54621384e-02,  1.96120011e-02, -3.50637293e-04],
#        ...,
#        [ 1.77887835e+00,  2.73133297e+00,  2.83222793e-02, ...,
#         -2.64156217e-02,  1.26778398e-02, -3.71185216e-03],
#        [ 1.79589397e+00,  2.71516839e+00,  1.48468080e-01, ...,
#         -2.97701257e-02, -2.49967470e-02,  4.01381944e-04],
#        [ 1.90451734e+00,  2.57907549e+00,  5.70943083e-02, ...,
#         -3.81317273e-02, -1.80879099e-02,  2.89144988e-04]])

# %%
pca.explained_variance_ratio_
# Out:
# array([4.76205247e-01, 2.63192760e-01, 1.07800432e-01, 1.02024637e-01,
#        3.30672372e-02, 1.60477360e-02, 1.42743130e-03, 2.34365001e-04,
#        1.53917702e-07])

# %%
plt.figure()
plt.plot(np.cumsum(pca.explained_variance_ratio_))
plt.xlabel('Dimension')
plt.ylabel('EVR')
# Out:
# Text(0, 0.5, 'EVR')

# %%
sigma=np.cov(data)

# %%
l,x=np.linalg.eig(data.T@data/213)

# %%
l
# Out:
# array([5.57660589e+03, 2.99545998e+00, 1.62501246e+00, 6.63863478e-01,
#        2.53225261e-01, 1.45249794e-01, 9.97976201e-02, 3.18878641e-06,
#        8.81858377e-03])

# %%
x
# Out:
# array([[-2.03790928e-02,  9.57252843e-05, -3.86663742e-03,
#          1.55306125e-03, -1.77182320e-02, -3.19569352e-02,
#         -5.81076953e-03, -9.99084000e-01,  5.43467370e-03],
#        [-1.79962983e-01,  7.75835662e-03,  3.92081555e-01,
#          7.30117765e-01, -5.19852053e-01, -7.59530965e-02,
#         -6.42334272e-02,  1.54167458e-02,  1.93545343e-02],
#        [-3.59809934e-02, -7.20479111e-01, -5.58080372e-01,
#          1.71873284e-01, -1.14285830e-01, -3.31873767e-01,
#         -1.22226515e-01,  1.63657280e-02, -1.45768712e-02],
#        [-1.93898237e-02,  4.49711557e-02,  2.70029770e-01,
#         -2.17324382e-01,  6.55509837e-02, -3.67053503e-01,
#         -8.59101059e-01,  1.45218258e-02, -1.28431871e-02],
#        [-9.75206605e-01, -5.93355525e-02,  1.84599040e-02,
#         -1.45585581e-01,  1.31320901e-01,  6.79278444e-02,
#          4.28109044e-02,  1.48278768e-02, -1.85223242e-03],
#        [-6.64429842e-03, -7.66324899e-02,  1.23336860e-01,
# ...

# %%
pc1=data@x[:,0]

# %%
pc2=data@x[:,1]

# %%
pca1=PCA(n_components=5)
new_data=pca1.fit_transform(data)

# %%
new_data
# Out:
# array([[-1.43142469, -1.10211499, -1.0669584 , -0.15823696,  0.14308027],
#        [-1.43670679,  0.34358527, -0.2778236 , -0.29393676, -0.19443421],
#        [-1.42732181,  0.3457201 ,  0.13870761, -0.32198409,  0.0237198 ],
#        ...,
#        [ 1.77887835,  2.73133297,  0.02832228, -0.51502563,  0.79733072],
#        [ 1.79589397,  2.71516839,  0.14846808, -0.66090378,  0.69437156],
#        [ 1.90451734,  2.57907549,  0.05709431, -0.42630635,  0.88271462]])

# %%
x=pd.DataFrame(new_data,columns=['pc1','pc2','pc3','pc4','pc5'])

# %%
y=df.Class

# %%
x
# Out:
#           pc1       pc2       pc3       pc4       pc5
# 0   -1.431425 -1.102115 -1.066958 -0.158237  0.143080
# 1   -1.436707  0.343585 -0.277824 -0.293937 -0.194434
# 2   -1.427322  0.345720  0.138708 -0.321984  0.023720
# 3   -1.257825 -0.249060  0.057742  0.022271  0.002472
# 4   -1.312466 -0.018405  0.357510 -0.278564 -0.071025
# ..        ...       ...       ...       ...       ...
# 209  2.273596  2.131266 -0.303368  0.213925  0.754221
# 210  1.758894  2.890519 -0.579363 -0.514717  0.570620
# 211  1.778878  2.731333  0.028322 -0.515026  0.797331
# 212  1.795894  2.715168  0.148468 -0.660904  0.694372
# 213  1.904517  2.579075  0.057094 -0.426306  0.882715
#
# [214 rows x 5 columns]

# %%
x1=df.iloc[:,1:-1]

# %%
x1
# Out:
#           RI     Na    Mg    Al     Si     K    Ca    Ba   Fe
# 0    1.52101  13.64  4.49  1.10  71.78  0.06  8.75  0.00  0.0
# 1    1.51761  13.89  3.60  1.36  72.73  0.48  7.83  0.00  0.0
# 2    1.51618  13.53  3.55  1.54  72.99  0.39  7.78  0.00  0.0
# 3    1.51766  13.21  3.69  1.29  72.61  0.57  8.22  0.00  0.0
# 4    1.51742  13.27  3.62  1.24  73.08  0.55  8.07  0.00  0.0
# ..       ...    ...   ...   ...    ...   ...   ...   ...  ...
# 209  1.51623  14.14  0.00  2.88  72.61  0.08  9.18  1.06  0.0
# 210  1.51685  14.92  0.00  1.99  73.06  0.00  8.40  1.59  0.0
# 211  1.52065  14.36  0.00  2.02  73.42  0.00  8.44  1.64  0.0
# 212  1.51651  14.38  0.00  1.94  73.61  0.00  8.48  1.57  0.0
# 213  1.51711  14.23  0.00  2.08  73.36  0.00  8.62  1.67  0.0
#
# [214 rows x 9 columns]

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn import tree

# %%
dt=DecisionTreeClassifier()
dt.fit(x,y)
# Out:
# DecisionTreeClassifier()

# %%
dt.predict(pca1.transform(sc.transform([[1.52101,13.64,4.49,1.10,71.78,0.06,8.75,0.0,0.0]])))
# Out:
# C:\Users\ASUSZenBook\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\ASUSZenBook\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but PCA was fitted with feature names
#   warnings.warn(
# C:\Users\ASUSZenBook\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(
# array([1], dtype=int64)
